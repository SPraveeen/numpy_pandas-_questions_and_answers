# %%
# The 5 V's of Big Data
# | Aspect   | Definition                                                               |
# |----------|--------------------------------------------------------------------------|
# | Volume   | The amount of data.                                                       |
# | Velocity | The speed at which data is generated and processed.                       |
# | Variety  | The different types of data (structured, unstructured, semi-structured).  |
# | Veracity | The reliability and accuracy of the data.                                 |
# | Value    | The usefulness of the data.                                               |
#
# Easy Mnemonic: "V4s Make Very Valuable Data!"
#
# V4s = Volume, Variety, Velocity, Veracity
#
# Make = Value

# %% [markdown]
# - What is the default storage format for data in Google BigQuery?
# - Avro

# %% [markdown]
# - What is the primary purpose of Google BigQuery?
# - To run SQL queries on large datasets

# %% [markdown]
# - The data to be loaded into the BigQuery from the cloud storage can be of ______ format. Choose the correct option from the list below.
# - CSV, JSON, Avro, Parquet, ORC

# %% [markdown]
# - Which is the right way to refer to a table in BigQuery?
#
# - Note: The name of the project is project, the name of the dataset is dataset and the name of the table is table.
#
# - `project.dataset.table`

# %% [markdown]
# - Which library installation from the options is not required while setting up BigQuery on a Jupyter Notebook?
# - pip install sklearn

# %% [markdown]
# - What is the Type of a Nested column, which is reflected in the table schema?
# - STRUCT

# %% [markdown]
# - The SQL function used to flatten repeated data before querying is?
# - unnest()

# %% [markdown]
# - Which of the following is NOT a good practice for optimizing SQL queries?
# - Avoid using EXISTS in subqueries

# %% [markdown]
# - Which of the following query is more efficient in terms of execution time for calculating “the 3rd highest salary of an employee”?
# - SELECT x.* FROM (SELECT * FROM emp ORDER BY salary DESC LIMIT 3) AS x ORDER BY x.salary ASC LIMIT 1;

# %% [markdown]
# - Context:
#
# - As part of an advanced database management course, your professor is focusing on the importance of indexing in SQL databases. Indexes play a crucial role in optimizing the performance of database queries, ensuring efficient data retrieval, and maintaining overall database performance.
#
# - Task:
#
# - During a lecture on database optimization, your professor asks you to identify the correct statement about the purpose of indexes in SQL databases.
#
# - Question:
#
# - Point out the correct statement:
#
# - Ans - Indexes are special lookup tables that the database search engine can use to speed up data retrieval.

# %% [markdown]
# - As a data engineering intern at Pied Piper, you are learning about database indexing and its impact on query performance. Your mentor emphasizes the importance of knowing which queries benefit the most from indexing to optimize the database efficiently.
# - SELECT * FROM emp WHERE salary >= 10000;

# %% [markdown]
# - Which of the following operations on partitioned tables is not supported via the Console?
# - DELETION

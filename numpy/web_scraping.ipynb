# %%
import requests

# %%
import os
from PIL import Image
from IPython.display import IFrame

# %%
url='https://www.ibm.com/'
r=requests.get(url)
r.status_code
# Out:
# 200

# %%
print(r.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.32.3', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_abck=8177F3459D8F9E0F850023369826CF3D~-1~...~-1~-1~-1~-1~-1; bm_sz=0009BEB44FBD5949AC65D73FB340F3BE~~4337730~3618616'}

# %%
print(r.request.body)
# Out:
# None

# %%
header=r.headers
print(header)
# Out:
# {'Content-Security-Policy': 'upgrade-insecure-requests', 'x-frame-options': 'SAMEORIGIN', 'Last-Modified': 'Thu, 15 Jan 2026 12:46:25 GMT', 'ETag': 'W/"32b76-6486c9cd4f482-gzip"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/html;charset=utf-8', 'X-Content-Type-Options': 'nosniff', 'Cache-Control': 'max-age=600', 'Expires': 'Thu, 15 Jan 2026 13:00:15 GMT', 'X-Akamai-Transformed': '0 - 0 -', 'Content-Encoding': 'gzip', 'Date': 'Thu, 15 Jan 2026 12:50:15 GMT', 'Content-Length': '39293', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000'}

# %%
header['Date']
# Out:
# 'Thu, 15 Jan 2026 12:50:15 GMT'

# %%
header['Content-Type']
# Out:
# 'text/html;charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text[0:100]
# Out:
# ' \n<!DOCTYPE HTML>\n\n<html lang="en">\n<head>\r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n    \r\n      \r\n    \r\n'

# %%
import requests

# %%
import os
from PIL import Image
from IPython.display import IFrame

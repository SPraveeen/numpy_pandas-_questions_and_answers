# %% [markdown]
# ![image.png](attachment:f71c19ac-cc29-4da2-af27-6166979671c4.png)

# %% [markdown]
# ![image.png](attachment:160c131d-f36a-482c-b0e8-1fbd1e6f4103.png)

# %% [markdown]
# ![image.png](attachment:642d5ee9-ac62-4b10-a08e-50993708e635.png)

# %% [markdown]
# ![image.png](attachment:bbc4ec28-e6dc-4ac7-a8cc-c97df057289b.png)

# %% [markdown]
# ![image.png](attachment:021bb99a-1719-49ab-ac01-72d3f5f8c068.png)

# %% [markdown]
# ![image.png](attachment:5b5f785f-aadf-48f1-b9f0-211d4c780a71.png)

# %% [markdown]
# ![image.png](attachment:436dbfe4-bd89-4a50-b40b-78cd640837b3.png)

# %% [markdown]
# ![image.png](attachment:8117e0d5-b8c4-44f2-a671-aded8d5da15f.png)

# %% [markdown]
# ![image.png](attachment:2a98cf06-9e04-4a52-aa10-1747eab6d034.png)

# %% [markdown]
# ![image.png](attachment:3e0d4398-f345-4231-90b5-aa020f6ef8ba.png)
